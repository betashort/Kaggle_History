# %% [markdown]
# https://www.kaggle.com/davidcairuz/feature-engineering-lightgbm

# %%
import os
import platform

import pandas as pd
import numpy as np
from tqdm import tqdm_notebook
from sklearn.metrics import roc_auc_score
import gc

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
print(platform.system())
if platform.system() == 'Darwin':
    path = "/Volumes/Buffalo-SSD/Kaggle_Datasets/Kaggle_IEEE_FraudDetection/input/"
elif platform.system() == 'Windows':
    path = "D:/Kaggle_Datasets/Kaggle_IEEE_FraudDetection/input/"
# Out:
# Windows

# %%
# %%time
os.listdir(path)
# Out:
# Wall time: 996 µs
# ['test_transaction.csv',
#  '._test_transaction.csv',
#  'train_identity.csv',
#  '._train_identity.csv',
#  'test_identity.csv',
#  '._test_identity.csv',
#  'sample_submission.csv',
#  '._sample_submission.csv',
#  'train_transaction.csv',
#  '._train_transaction.csv',
#  'train_feature1.csv',
#  'test_feature1.csv',
#  'train_upsampled.csv',
#  'val_data.csv',
#  'train_downsampled.csv',
#  'train_upsampled_all.csv',
#  'train_downsampled_all.csv',
#  'train_rus.csv',
#  'train_ros.csv',
#  'train_tl.csv']

# %%
# %%time
train = pd.read_csv(f'{path}train_upsampled_all.csv')
# Out:
# Wall time: 29.6 s

# %%
test = pd.read_csv(f'{path}test_feature1.csv')

# %%
train.shape
# Out:
# (1139754, 339)

# %%
train.head()
# Out:
#    Unnamed: 0  TransactionID  isFraud  TransactionDT  TransactionAmt  \
# 0           0        2987000        0          86400            68.5
# 1           1        2987001        0          86401            29.0
# 2           2        2987002        0          86469            59.0
# 3           3        2987003        0          86499            50.0
# 4           4        2987004        0          86506            50.0
#
#    ProductCD  card1  card2  card3  card4          ...           \
# 0          4  13926    NaN  150.0      1          ...
# 1          4   2755  404.0  150.0      2          ...
# 2          4   4663  490.0  150.0      4          ...
# 3          4  18132  567.0  150.0      2          ...
# 4          1   4497  514.0  150.0      2          ...
#
#    card6_count_full  id_36_count_full  id_01_count_dist  id_31_count_dist  \
# 0            267648            819269            446307            450258
# 1            267648            819269            446307            450258
# 2            824959            819269            446307            450258
# 3            824959            819269            446307            450258
# 4            267648            267353             19555              1061
#
#    id_33_count_dist  id_36_count_dist  P_emaildomain_bin  \
# 0            517251            449555                  6
# 1            517251            449555                  4
# 2            517251            449555                  5
# 3            517251            449555                  9
# 4               544            134066                  4
#
#    P_emaildomain_suffix  R_emaildomain_bin  R_emaildomain_suffix
# 0                     6                  6                     6
# 1                     0                  6                     6
# 2                     0                  6                     6
# 3                     0                  6                     6
# 4                     0                  6                     6
#
# [5 rows x 339 columns]

# %%
test.shape
# Out:
# (506691, 337)

# %%
test.head()
# Out:
#    TransactionID  TransactionDT  TransactionAmt  ProductCD  card1  card2  \
# 0        3663549       18403224           31.95          4  10409  111.0
# 1        3663550       18403263           49.00          4   4272  111.0
# 2        3663551       18403310          171.00          4   4476  574.0
# 3        3663552       18403310          285.00          4  10989  360.0
# 4        3663553       18403317           67.94          4  18018  452.0
#
#    card3  card4  card5  card6          ...           card6_count_full  \
# 0  150.0      4  226.0      2          ...                     824959
# 1  150.0      4  226.0      2          ...                     824959
# 2  150.0      4  226.0      2          ...                     824959
# 3  150.0      4  166.0      2          ...                     824959
# 4  150.0      2  117.0      2          ...                     824959
#
#    id_36_count_full  id_01_count_dist  id_31_count_dist  id_33_count_dist  \
# 0            819269            364784            370066            436020
# 1            819269            364784            370066            436020
# 2            819269            364784            370066            436020
# 3            819269            364784            370066            436020
# 4            819269            364784            370066            436020
#
#    id_36_count_dist  P_emaildomain_bin  P_emaildomain_suffix  \
# 0            369714                  4                     0
# 1            369714                  0                     0
# 2            369714                  5                     0
# 3            369714                  4                     0
# 4            369714                  4                     0
#
#    R_emaildomain_bin  R_emaildomain_suffix
# 0                  6                     6
# 1                  6                     6
# 2                  6                     6
# 3                  6                     6
# 4                  6                     6
#
# [5 rows x 337 columns]

# %%
X = train.sort_values('TransactionDT').drop(['Unnamed: 0', 'TransactionID', 'isFraud', 'TransactionDT'], axis=1)
y = train.sort_values('TransactionDT')['isFraud']

X_test = test.drop(['TransactionID', 'TransactionDT'], axis=1)

gc.collect()
# Out:
# 11

# %%
print(X.shape)
X.head()
# Out:
# (1139754, 335)
#    TransactionAmt  ProductCD  card1  card2  card3  card4  card5  card6  addr1  \
# 0            68.5          4  13926    NaN  150.0      1  142.0      1  315.0
# 1            29.0          4   2755  404.0  150.0      2  102.0      1  325.0
# 2            59.0          4   4663  490.0  150.0      4  166.0      2  330.0
# 3            50.0          4  18132  567.0  150.0      2  117.0      2  476.0
# 4            50.0          1   4497  514.0  150.0      2  102.0      1  420.0
#
#    addr2          ...           card6_count_full  id_36_count_full  \
# 0   87.0          ...                     267648            819269
# 1   87.0          ...                     267648            819269
# 2   87.0          ...                     824959            819269
# 3   87.0          ...                     824959            819269
# 4   87.0          ...                     267648            267353
#
#    id_01_count_dist  id_31_count_dist  id_33_count_dist  id_36_count_dist  \
# 0            446307            450258            517251            449555
# 1            446307            450258            517251            449555
# 2            446307            450258            517251            449555
# 3            446307            450258            517251            449555
# 4             19555              1061               544            134066
#
#    P_emaildomain_bin  P_emaildomain_suffix  R_emaildomain_bin  \
# 0                  6                     6                  6
# 1                  4                     0                  6
# 2                  5                     0                  6
# 3                  9                     0                  6
# 4                  4                     0                  6
#
#    R_emaildomain_suffix
# 0                     6
# 1                     6
# 2                     6
# 3                     6
# 4                     6
#
# [5 rows x 335 columns]

# %%
print(X_test.shape)
X_test.head()
# Out:
# (506691, 335)
#    TransactionAmt  ProductCD  card1  card2  card3  card4  card5  card6  addr1  \
# 0           31.95          4  10409  111.0  150.0      4  226.0      2  170.0
# 1           49.00          4   4272  111.0  150.0      4  226.0      2  299.0
# 2          171.00          4   4476  574.0  150.0      4  226.0      2  472.0
# 3          285.00          4  10989  360.0  150.0      4  166.0      2  205.0
# 4           67.94          4  18018  452.0  150.0      2  117.0      2  264.0
#
#    addr2          ...           card6_count_full  id_36_count_full  \
# 0   87.0          ...                     824959            819269
# 1   87.0          ...                     824959            819269
# 2   87.0          ...                     824959            819269
# 3   87.0          ...                     824959            819269
# 4   87.0          ...                     824959            819269
#
#    id_01_count_dist  id_31_count_dist  id_33_count_dist  id_36_count_dist  \
# 0            364784            370066            436020            369714
# 1            364784            370066            436020            369714
# 2            364784            370066            436020            369714
# 3            364784            370066            436020            369714
# 4            364784            370066            436020            369714
#
#    P_emaildomain_bin  P_emaildomain_suffix  R_emaildomain_bin  \
# 0                  4                     0                  6
# 1                  0                     0                  6
# 2                  5                     0                  6
# 3                  4                     0                  6
# 4                  4                     0                  6
#
#    R_emaildomain_suffix
# 0                     6
# 1                     6
# 2                     6
# 3                     6
# 4                     6
#
# [5 rows x 335 columns]

# %%
del(train, test)

# %%
from sklearn.model_selection import KFold
import lightgbm as lgb

# %%
params = {'num_leaves': 491,
          'min_child_weight': 0.03454472573214212,
          'feature_fraction': 0.3797454081646243,
          'bagging_fraction': 0.4181193142567742,
          'min_data_in_leaf': 106,
          'objective': 'binary',
          'max_depth': -1,
          'learning_rate': 0.006883242363721497,
          "boosting_type": "gbdt",
          "bagging_seed": 11,
          "metric": 'auc',
          "verbosity": -1,
          'reg_alpha': 0.3899927210061127,
          'reg_lambda': 0.6485237330340494,
          'random_state': 47,
         }

# %%
# %%time

NFOLDS = 5
folds = KFold(n_splits=NFOLDS)

columns = X.columns
splits = folds.split(X, y)
y_preds = np.zeros(X_test.shape[0])
y_oof = np.zeros(X.shape[0])
score = 0

feature_importances = pd.DataFrame()
feature_importances['feature'] = columns
  
for fold_n, (train_index, valid_index) in enumerate(splits):
    X_train, X_valid = X[columns].iloc[train_index], X[columns].iloc[valid_index]
    y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
    
    dtrain = lgb.Dataset(X_train, label=y_train)
    dvalid = lgb.Dataset(X_valid, label=y_valid)

    clf = lgb.train(params, dtrain, 10000, valid_sets = [dtrain, dvalid], verbose_eval=200, early_stopping_rounds=500)
    
    feature_importances[f'fold_{fold_n + 1}'] = clf.feature_importance()
    
    y_pred_valid = clf.predict(X_valid)
    y_oof[valid_index] = y_pred_valid
    print(f"Fold {fold_n + 1} | AUC: {roc_auc_score(y_valid, y_pred_valid)}")
    
    score += roc_auc_score(y_valid, y_pred_valid) / NFOLDS
    y_preds += clf.predict(X_test) / NFOLDS
    
    del X_train, X_valid, y_train, y_valid
    gc.collect()
    
print(f"\nMean AUC = {score}")
print(f"Out of folds AUC = {roc_auc_score(y, y_oof)}")
# Out:
# Training until validation scores don't improve for 500 rounds.
# [200]	training's auc: 0.975102	valid_1's auc: 0.895181
# [400]	training's auc: 0.987392	valid_1's auc: 0.902633
# [600]	training's auc: 0.994093	valid_1's auc: 0.90969
# [800]	training's auc: 0.997311	valid_1's auc: 0.914512
# [1000]	training's auc: 0.99873	valid_1's auc: 0.91749
# [1200]	training's auc: 0.999371	valid_1's auc: 0.918785
# [1400]	training's auc: 0.999686	valid_1's auc: 0.919533
# [1600]	training's auc: 0.999841	valid_1's auc: 0.919512
# [1800]	training's auc: 0.99992	valid_1's auc: 0.919266
# Early stopping, best iteration is:
# [1438]	training's auc: 0.999725	valid_1's auc: 0.919616
# Fold 1 | AUC: 0.9196157310209107
# Training until validation scores don't improve for 500 rounds.
# [200]	training's auc: 0.973094	valid_1's auc: 0.919029
# [400]	training's auc: 0.986905	valid_1's auc: 0.927961
# [600]	training's auc: 0.993912	valid_1's auc: 0.934699
# [800]	training's auc: 0.997203	valid_1's auc: 0.938607
# [1000]	training's auc: 0.998689	valid_1's auc: 0.940547
# [1200]	training's auc: 0.999369	valid_1's auc: 0.941516
# [1400]	training's auc: 0.999691	valid_1's auc: 0.941571
# [1600]	training's auc: 0.999843	valid_1's auc: 0.941686
# [1800]	training's auc: 0.999922	valid_1's auc: 0.941846
# [2000]	training's auc: 0.999961	valid_1's auc: 0.942185
# [2200]	training's auc: 0.999982	valid_1's auc: 0.942199
# [2400]	training's auc: 0.999992	valid_1's auc: 0.942275
# [2600]	training's auc: 0.999997	valid_1's auc: 0.942377
# [2800]	training's auc: 0.999999	valid_1's auc: 0.94247
# [3000]	training's auc: 1	valid_1's auc: 0.942483
# [3200]	training's auc: 1	valid_1's auc: 0.942455
# [3400]	training's auc: 1	valid_1's auc: 0.942203
# Early stopping, best iteration is:
# [3016]	training's auc: 1	valid_1's auc: 0.942521
# Fold 2 | AUC: 0.9425211540213843
# Training until validation scores don't improve for 500 rounds.
# [200]	training's auc: 0.974498	valid_1's auc: 0.913813
# [400]	training's auc: 0.987376	valid_1's auc: 0.921304
# [600]	training's auc: 0.994082	valid_1's auc: 0.925962
# [800]	training's auc: 0.99729	valid_1's auc: 0.928429
# [1000]	training's auc: 0.998702	valid_1's auc: 0.929634
# [1200]	training's auc: 0.99934	valid_1's auc: 0.930034
# [1400]	training's auc: 0.999668	valid_1's auc: 0.930102
# [1600]	training's auc: 0.999835	valid_1's auc: 0.930206
# [1800]	training's auc: 0.999917	valid_1's auc: 0.930069
# [2000]	training's auc: 0.999958	valid_1's auc: 0.930242
# [2200]	training's auc: 0.99998	valid_1's auc: 0.930298
# [2400]	training's auc: 0.999991	valid_1's auc: 0.930324
# [2600]	training's auc: 0.999996	valid_1's auc: 0.930555
# [2800]	training's auc: 0.999998	valid_1's auc: 0.930692
# [3000]	training's auc: 0.999999	valid_1's auc: 0.931065
# [3200]	training's auc: 1	valid_1's auc: 0.931326
# [3400]	training's auc: 1	valid_1's auc: 0.931467
# [3600]	training's auc: 1	valid_1's auc: 0.931417
# [3800]	training's auc: 1	valid_1's auc: 0.931443
# Early stopping, best iteration is:
# [3418]	training's auc: 1	valid_1's auc: 0.931484
# Fold 3 | AUC: 0.9314838340970597
# Training until validation scores don't improve for 500 rounds.
# [200]	training's auc: 0.973142	valid_1's auc: 0.931301
# [400]	training's auc: 0.986843	valid_1's auc: 0.939774
# [600]	training's auc: 0.99393	valid_1's auc: 0.945159
# [800]	training's auc: 0.99725	valid_1's auc: 0.948042
# [1000]	training's auc: 0.998697	valid_1's auc: 0.94905
# [1200]	training's auc: 0.999341	valid_1's auc: 0.949339
# [1400]	training's auc: 0.999667	valid_1's auc: 0.949363
# [1600]	training's auc: 0.999827	valid_1's auc: 0.949227
# [1800]	training's auc: 0.999914	valid_1's auc: 0.948973
# Early stopping, best iteration is:
# [1390]	training's auc: 0.999656	valid_1's auc: 0.949399
# Fold 4 | AUC: 0.9493989598926112
# Training until validation scores don't improve for 500 rounds.
# [200]	training's auc: 0.97403	valid_1's auc: 0.907832
# [400]	training's auc: 0.987267	valid_1's auc: 0.917458
# [600]	training's auc: 0.994157	valid_1's auc: 0.923166
# [800]	training's auc: 0.99735	valid_1's auc: 0.926126
# [1000]	training's auc: 0.998752	valid_1's auc: 0.92698
# [1200]	training's auc: 0.999372	valid_1's auc: 0.9269
# [1400]	training's auc: 0.99968	valid_1's auc: 0.926308
# Early stopping, best iteration is:
# [1036]	training's auc: 0.998901	valid_1's auc: 0.927202
# Fold 5 | AUC: 0.9272018125525855
#
# Mean AUC = 0.9340442983169103
# Out of folds AUC = 0.9180475533265191
# Wall time: 1h 7min 16s

# %%
sub = pd.read_csv(f'{path}sample_submission.csv')

# %%
sub['isFraud'] = y_preds
sub.to_csv("feature1_oversampled.csv", index=False)

# %%
feature_importances['average'] = feature_importances[[f'fold_{fold_n + 1}' for fold_n in range(folds.n_splits)]].mean(axis=1)
feature_importances.to_csv('feature1_oversampled_importances.csv')

plt.figure(figsize=(16, 16))
sns.barplot(data=feature_importances.sort_values(by='average', ascending=False).head(50), x='average', y='feature');
plt.title('50 TOP feature importance over {} folds average'.format(folds.n_splits));

# %%
feature_importances.sort_values(by='average', ascending=False).head(50)
# Out:
#                           feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 319                  addr1__card1   22537   46280   51596   21327   16372
# 320              card1_count_full   22011   44780   50672   21106   16229
# 2                           card1   21494   43870   48620   20136   15647
# 316                  card1__card5   20906   41469   45696   19412   14651
# 289   TransactionAmt_to_std_card1   16362   39027   45682   15724   10826
# 288  TransactionAmt_to_mean_card1   14608   34611   39982   13169    9191
# 321              card2_count_full   15921   32032   36243   15132   11833
# 3                           card2   15780   31604   36068   14657   10780
# 8                           addr1   14755   30883   34615   14418   11344
# 292  TransactionAmt_to_mean_addr1   12719   28959   33940   12249    9010
# 315                  card2__dist1   13658   27452   31100   12909   10180
# 293   TransactionAmt_to_std_addr1   12491   27860   31507   11598    8780
# 318          card5__P_emaildomain   12561   25346   28478   11501    8601
# 291   TransactionAmt_to_std_card4   10737   24073   27805   10310    6833
# 290  TransactionAmt_to_mean_card4   10072   24033   26603    9796    6973
# 10                          dist1   11256   21270   24859   10610    8311
# 314             P_emaildomain__C2   10867   21988   24130   10431    8156
# 0                  TransactionAmt    9519   22015   24959    8800    6357
# 309              Transaction_hour    8659   21309   25706    8200    5506
# 317                  card2__id_20    8953   20575   23724    8769    6452
# 27                             D2   10027   17229   18620    9361    7493
# 29                             D4    9470   18340   19622    8774    6475
# 24                            C13    9948   16798   17460    9565    7713
# 300             D15_to_mean_card1    8779   15682   17736    8008    6013
# 307        TransactionAmt_decimal    6950   16926   20101    6222    4471
# 34                            D10    7667   14720   16875    7689    6018
# 308       Transaction_day_of_week    5926   16626   18181    5663    3517
# 26                             D1    7934   13809   14825    7401    5914
# 301              D15_to_std_card1    7144   13448   15629    6666    5260
# 313     DeviceInfo__P_emaildomain    6029   13664   15895    5893    4274
# 306            TransactionAmt_Log    5670   14133   16061    5259    4126
# 35                            D11    6925   13560   14051    5628    4442
# 304             D15_to_mean_addr1    6384   11775   13549    6239    4827
# 269                         id_20    5258   12567   14936    5559    3410
# 13                             C1    6456   11440   12491    6171    5004
# 302             D15_to_mean_card4    5943   11754   12939    5694    4649
# 11                  P_emaildomain    5782   10959   12318    5261    4069
# 6                           card5    5275   10716   11904    5183    3934
# 14                             C2    5615   10139   11268    5094    4079
# 32                             D8    4774   10404   11988    4987    3791
# 39                            D15    5026   10267   11623    4949    3842
# 25                            C14    5495    9700   10697    5120    4129
# 305              D15_to_std_addr1    5091    9660   11229    5015    3964
# 268                         id_19    4291   11067   12580    4182    2820
# 324              card5_count_full    4846   10028   11403    4538    3502
# 331             P_emaildomain_bin    4766    9721   10686    4274    3249
# 30                             D5    4235    9715   11106    4255    3011
# 17                             C6    4654    8809    9399    4513    3530
# 303              D15_to_std_card4    4782    8561    9189    4502    3339
# 22                            C11    4564    8296    8713    4276    3462
#
#      average
# 319  31622.4
# 320  30959.6
# 2    29953.4
# 316  28426.8
# 289  25524.2
# 288  22312.2
# 321  22232.2
# 3    21777.8
# 8    21203.0
# 292  19375.4
# 315  19059.8
# 293  18447.2
# 318  17297.4
# 291  15951.6
# 290  15495.4
# 10   15261.2
# 314  15114.4
# 0    14330.0
# 309  13876.0
# 317  13694.6
# 27   12546.0
# 29   12536.2
# 24   12296.8
# 300  11243.6
# 307  10934.0
# 34   10593.8
# 308   9982.6
# 26    9976.6
# 301   9629.4
# 313   9151.0
# 306   9049.8
# 35    8921.2
# 304   8554.8
# 269   8346.0
# 13    8312.4
# 302   8195.8
# 11    7677.8
# 6     7402.4
# 14    7239.0
# 32    7188.8
# 39    7141.4
# 25    7028.2
# 305   6991.8
# 268   6988.0
# 324   6863.4
# 331   6539.2
# 30    6464.4
# 17    6181.0
# 303   6074.6
# 22    5862.2
